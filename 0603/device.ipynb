# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 4910295222845918936, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 12991493671149426852
#  physical_device_desc: "device: XLA_CPU device"]

# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.2.4'
